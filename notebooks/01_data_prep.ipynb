# %%
from pathlib import Path

import pandas as pd

from src.data_loader import load_f1_data

project_root = Path('..').resolve()
seasons = [2022, 2023, 2024, 2025]
raw_df = load_f1_data(seasons)
raw_df.head()
